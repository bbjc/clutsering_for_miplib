# %% [markdown]
# # Demonstrating the Framework with a Small Example
#
# In this Jupyter notebook, we illustrate the functionality of the framework. We provide a simple example where we generate instances of the GISP problem, along with a training set and a test set. The GP function is trained on the training set and evaluated on the test set.

# %% [markdown]
# ## Generating Training and Test Instances
#
# In this notebook, we focus on training and testing for the GISP problem. The corresponding data is stored in the directories `"data/gisp/train_for_jupyter"` and `"data/gisp/test_for_jupyter"`. To reduce computation time, the training set is limited to 10 instances, with the number of nodes in the problem (which determines the complexity) ranging between 40 and 50.
#
# The instances are generated as follows:

# %%
import os
import shutil
import conf
from data.build_gisp_instances import *

# Note: The construction of the instance reuses the code by Labassi et al. on Graph Neural Networks.

# Parameters for instance generation
n = 10  # Number of training instances
whichSet = 'SET2'  # Set identifier, must be set to 'SET2'
setparam = 100  # Parameter related to "revenues"
alphaE2 = 0.5  # Probability of building an edge

# Graph parameters for GISP problem representation
min_n = 40  # Minimum number of nodes in the graph
max_n = 50  # Maximum number of nodes in the graph
er_prob = 0.6  # Erdos-Rényi random graph parameter

# Directory for training instances
lp_dir_training = os.path.join(conf.ROOT_DIR, "data/gisp/train_for_jupyter")
if os.path.exists(lp_dir_training):
    print(f"Cleaning directory: {lp_dir_training}")
    try:
        shutil.rmtree(lp_dir_training)  # Recursively removes a directory and all its contents
    except Exception as e:
        print(f"Error cleaning {lp_dir_training}: {e}")
else:
    os.mkdir(lp_dir_training)

# Generate training instances
generate_instances(n, whichSet, setparam, alphaE2, min_n, max_n, er_prob, None, lp_dir_training, False)

# Parameters for test instance generation
n = 60  # Number of test instances, increased by 10 in case they are failures in the evaluation through all the baselines

# Directory for test instances
lp_dir_test = os.path.join(conf.ROOT_DIR, "data/gisp/test_for_jupyter")
if os.path.exists(lp_dir_test):
    print(f"Cleaning directory: {lp_dir_test}")
    try:
        shutil.rmtree(lp_dir_test)  # Recursively removes a directory and all its contents
    except Exception as e:
        print(f"Error cleaning {lp_dir_test}: {e}")
else:
    os.mkdir(lp_dir_test)

# Generate test instances
generate_instances(n, whichSet, setparam, alphaE2, min_n, max_n, er_prob, None, lp_dir_test, False)
# Out:
# Cleaning directory: C:\Users\gwen.maudet\OneDrive - University of Luxembourg\Documents\programs\PycharmProjects\post doc lux\genetic_programming_search_strategy\data/gisp/train_for_jupyter
# Error cleaning C:\Users\gwen.maudet\OneDrive - University of Luxembourg\Documents\programs\PycharmProjects\post doc lux\genetic_programming_search_strategy\data/gisp/train_for_jupyter: [WinError 5] Access is denied: 'C:\\Users\\gwen.maudet\\OneDrive - University of Luxembourg\\Documents\\programs\\PycharmProjects\\post doc lux\\genetic_programming_search_strategy\\data/gisp/train_for_jupyter'
# Cleaning directory: C:\Users\gwen.maudet\OneDrive - University of Luxembourg\Documents\programs\PycharmProjects\post doc lux\genetic_programming_search_strategy\data/gisp/test_for_jupyter
# Error cleaning C:\Users\gwen.maudet\OneDrive - University of Luxembourg\Documents\programs\PycharmProjects\post doc lux\genetic_programming_search_strategy\data/gisp/test_for_jupyter: [WinError 5] Access is denied: 'C:\\Users\\gwen.maudet\\OneDrive - University of Luxembourg\\Documents\\programs\\PycharmProjects\\post doc lux\\genetic_programming_search_strategy\\data/gisp/test_for_jupyter'

# %% [markdown]
# ## Training the GP
#
# With this dataset, the GP2S algorithm can now be trained. By default, if the problem is one of the three artificial problems, the algorithm will search for data in `data/problem/training_folder`. The initial population is set to 30, with 10 generations, which can still be time-consuming. However, smaller values can be used if the goal is simply to run the algorithm quickly.

# %%
from genetic_programming_for_node_scoring import *
import os

# Parameters for GP_function training
problem = "gisp"  # Problem type
training_folder = "train_for_jupyter"
initial_pop = 30  # Population size for tree-based heuristics
mate = 0.9  # Crossover rate
mutate = 0.1  # Mutation rate
nb_of_gen = 10  # Number of generations
seed = 0  # Random seed
node_select = "BFS"  # Node selection method (BFS allows testing DFS as well)
saving_folder = os.path.join(conf.ROOT_DIR, "outcomes_jupyter/GP_function")

# Construct a unique name for the run
name = f"{problem}_pop_{initial_pop}_nb_gen{nb_of_gen}_seed_{seed}"

# Ensure the saving directory exists
if not os.path.exists(saving_folder):
    os.mkdir(saving_folder)

# Tournament parameters
fitness_size = 3  # Number of individuals in the fitness tournament
parsimony_size = 1.2  # Parameter for size-based tournament
time_limit = 0  # Time limit (not applicable for artificial problems)
nb_of_instances = 0  # Number of instances (not applicable for artificial problems)

# Run the GP_function training
main_GP(
    problem=problem,
    initial_pop=initial_pop,
    mate=mate,
    mutate=mutate,
    nb_of_gen=nb_of_gen,
    seed=seed,
    node_select=node_select,
    saving_folder=saving_folder,
    name=name,
    training_folder=training_folder,
    fitness_size=fitness_size,
    parsimony_size=parsimony_size,
    time_limit=time_limit,
    nb_of_instances=nb_of_instances
)
# Out:
# seed: 0
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.58
#
# protectedDiv(getEstimate, getLowerbound)
# mean solving time or gap:  0.58
#
# add(getLowerbound, sub(getNVars, 10000000))
# mean solving time or gap:  0.76
#
# protectedDiv(getLowerbound, getNConss)
# mean solving time or gap:  0.69
#
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.62
#
# add(getNVars, 10000000)
# mean solving time or gap:  0.58
#
# add(10000000, sub(add(getNConss, 10000000), protectedDiv(getLowerbound, protectedDiv(getNConss, getDepth))))
# mean solving time or gap:  0.52
#
# sub(mul(getNConss, mul(getLowerbound, 10000000)), getNConss)
# mean solving time or gap:  0.58
#
# protectedDiv(getNVars, sub(add(protectedDiv(mul(getEstimate, protectedDiv(getDualboundRoot, getNVars)), mul(getNConss, getNConss)), 10000000), getDepth))
# mean solving time or gap:  0.47
#
# add(mul(mul(getDepth, getEstimate), sub(getNConss, getNConss)), getDepth)
# mean solving time or gap:  0.47
#
# add(getNVars, getEstimate)
# mean solving time or gap:  0.71
#
# protectedDiv(10000000, add(getEstimate, sub(protectedDiv(getEstimate, getNVars), add(getNConss, getDualboundRoot))))
# mean solving time or gap:  0.64
#
# mul(getDepth, mul(getDepth, getDepth))
# mean solving time or gap:  0.58
#
# protectedDiv(getLowerbound, protectedDiv(sub(sub(10000000, getDepth), sub(10000000, getEstimate)), getLowerbound))
# mean solving time or gap:  0.37
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(mul(getEstimate, getEstimate), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# mul(getDualboundRoot, add(getEstimate, sub(getNVars, getNVars)))
# mean solving time or gap:  0.52
#
# add(getNVars, 10000000)
# mean solving time or gap:  0.47
#
# sub(getLowerbound, protectedDiv(getNConss, getDualboundRoot))
# mean solving time or gap:  0.47
#
# add(getDualboundRoot, getLowerbound)
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(protectedDiv(protectedDiv(getEstimate, 10000000), 10000000), add(getNConss, mul(getEstimate, 10000000)))))
# mean solving time or gap:  0.41
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getNConss, getEstimate), getLowerbound), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), sub(getDualboundRoot, add(10000000, getDepth))), 10000000)))
# mean solving time or gap:  0.41
#
# mul(getDepth, getDualboundRoot)
# mean solving time or gap:  0.47
#
# mul(mul(getDepth, protectedDiv(getLowerbound, sub(protectedDiv(add(getDepth, getEstimate), getDepth), getNConss))), getDualboundRoot)
# mean solving time or gap:  0.58
#
# sub(getLowerbound, getLowerbound)
# mean solving time or gap:  0.43
#
# protectedDiv(getDepth, 10000000)
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# add(getLowerbound, getDepth)
# mean solving time or gap:  0.41
#
# sub(getDualboundRoot, getNConss)
# mean solving time or gap:  0.47
#
# add(protectedDiv(getDualboundRoot, protectedDiv(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), add(getNVars, mul(getDepth, getNConss)))), getLowerbound)
# mean solving time or gap:  0.47
#
# protectedDiv(getNVars, protectedDiv(getDepth, getDepth))
# mean solving time or gap:  0.41
#
# gen	nevals	avg  	std      	min 	max
# 0  	30    	0.516	0.0985427	0.37	0.76
# add(getEstimate, getDepth)
# mean solving time or gap:  0.52
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(mul(getEstimate, mul(mul(getDepth, getEstimate), sub(getNConss, getNConss))), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# add(protectedDiv(getDualboundRoot, protectedDiv(protectedDiv(mul(10000000, getDualboundRoot), getNVars), add(getNVars, mul(getDepth, getNConss)))), getLowerbound)
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, sub(getNConss, getNConss))
# mean solving time or gap:  0.28
#
# protectedDiv(getLowerbound, protectedDiv(sub(getLowerbound, sub(10000000, getEstimate)), getLowerbound))
# mean solving time or gap:  0.89
#
# protectedDiv(sub(10000000, getDepth), protectedDiv(sub(sub(10000000, getDepth), sub(10000000, getEstimate)), getLowerbound))
# mean solving time or gap:  0.91
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(protectedDiv(protectedDiv(getEstimate, 10000000), 10000000), add(getNConss, getLowerbound))))
# mean solving time or gap:  0.52
#
# sub(mul(getEstimate, 10000000), getLowerbound)
# mean solving time or gap:  0.62
#
# protectedDiv(getNVars, sub(add(protectedDiv(mul(getEstimate, protectedDiv(getDualboundRoot, getNVars)), 10000000), 10000000), getDepth))
# mean solving time or gap:  0.41
#
# protectedDiv(mul(getNConss, getNConss), getNVars)
# mean solving time or gap:  0.47
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getNConss, protectedDiv(sub(sub(10000000, getDepth), sub(10000000, getEstimate)), getLowerbound)), getLowerbound), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), sub(getDualboundRoot, add(10000000, getDepth))), 10000000)))
# mean solving time or gap:  0.58
#
# protectedDiv(getLowerbound, getEstimate)
# mean solving time or gap:  0.62
#
# protectedDiv(10000000, protectedDiv(getLowerbound, sub(protectedDiv(protectedDiv(getEstimate, 10000000), 10000000), add(getNConss, mul(getEstimate, 10000000)))))
# mean solving time or gap:  0.52
#
# protectedDiv(getNVars, protectedDiv(sub(sub(10000000, getDepth), sub(10000000, getEstimate)), getLowerbound))
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, mul(getEstimate, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(getNVars, protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getNConss, getEstimate), getLowerbound), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), protectedDiv(getLowerbound, add(add(getLowerbound, getDepth), getNVars))), 10000000)))
# mean solving time or gap:  0.58
#
# add(protectedDiv(getDualboundRoot, getNVars), getLowerbound)
# mean solving time or gap:  0.47
#
# add(protectedDiv(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), add(getNVars, mul(getDepth, getNConss))), 10000000)
# mean solving time or gap:  0.47
#
# add(protectedDiv(getDualboundRoot, protectedDiv(protectedDiv(mul(sub(10000000, getEstimate), getDualboundRoot), sub(getNConss, getNConss)), add(getNVars, mul(getDepth, getNConss)))), getLowerbound)
# mean solving time or gap:  0.41
#
# protectedDiv(getLowerbound, protectedDiv(sub(sub(10000000, getDepth), 10000000), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(getLowerbound, protectedDiv(sub(getDepth, sub(10000000, getEstimate)), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(getLowerbound, protectedDiv(sub(sub(10000000, sub(10000000, getDepth)), sub(10000000, getEstimate)), getLowerbound))
# mean solving time or gap:  0.62
#
# protectedDiv(getLowerbound, getNVars)
# mean solving time or gap:  0.47
#
# sub(getLowerbound, 10000000)
# mean solving time or gap:  0.58
#
# 1  	25    	0.508667	0.132054 	0.28	0.91
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getDepth, getEstimate), getLowerbound), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), sub(getDualboundRoot, add(10000000, getDepth))), 10000000)))
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, protectedDiv(getDepth, getNConss))
# mean solving time or gap:  0.47
#
# protectedDiv(getNVars, protectedDiv(getDepth, getLowerbound))
# mean solving time or gap:  0.41
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getNConss, getEstimate), getDepth), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), sub(getDualboundRoot, add(10000000, getDepth))), 10000000)))
# mean solving time or gap:  0.58
#
# protectedDiv(getNVars, sub(add(getEstimate, 10000000), getDepth))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(getDualboundRoot, getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(sub(getDualboundRoot, getEstimate), sub(getNConss, getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, 10000000)
# mean solving time or gap:  0.47
#
# protectedDiv(getLowerbound, sub(protectedDiv(getEstimate, getEstimate), getNConss))
# mean solving time or gap:  0.62
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, sub(getNConss, mul(getEstimate, getEstimate)))
# mean solving time or gap:  0.47
#
# protectedDiv(mul(getNConss, getNConss), sub(getNConss, getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.37
#
# add(protectedDiv(getNVars, add(getNVars, mul(getDepth, getNConss))), 10000000)
# mean solving time or gap:  0.52
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getNConss, getEstimate), getLowerbound), getLowerbound), 10000000), sub(getDualboundRoot, add(10000000, getDepth))), 10000000)))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(protectedDiv(protectedDiv(getEstimate, mul(add(getEstimate, getNConss), getDualboundRoot)), 10000000), add(getNConss, getLowerbound))))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(getEstimate, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, sub(add(10000000, 10000000), getDepth))
# mean solving time or gap:  0.37
#
# add(protectedDiv(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), add(getNVars, mul(getDepth, getNConss))), protectedDiv(mul(getEstimate, protectedDiv(getDualboundRoot, getNVars)), 10000000))
# mean solving time or gap:  0.53
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, sub(getNConss, getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(10000000, add(getNConss, getLowerbound))))
# mean solving time or gap:  0.43
#
# protectedDiv(getLowerbound, protectedDiv(sub(sub(10000000, getDepth), protectedDiv(protectedDiv(getEstimate, 10000000), 10000000)), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(getLowerbound, protectedDiv(sub(getDualboundRoot, sub(getNVars, add(protectedDiv(add(getDualboundRoot, getNVars), getNVars), getEstimate))), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(sub(10000000, getDepth), mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(mul(getEstimate, mul(mul(getDepth, getEstimate), sub(getNConss, getNConss))), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(getDepth, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, protectedDiv(getDepth, 10000000))
# mean solving time or gap:  0.58
#
# 2  	30    	0.442   	0.0620967	0.37	0.62
# protectedDiv(getDepth, 10000000)
# mean solving time or gap:  0.52
#
# protectedDiv(getNVars, getNConss)
# mean solving time or gap:  0.58
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(add(10000000, 10000000), getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.47
#
# protectedDiv(add(getLowerbound, protectedDiv(mul(sub(getDualboundRoot, 10000000), getEstimate), getNVars)), sub(getDualboundRoot, getDepth))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(10000000, getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, getNVars)
# mean solving time or gap:  0.47
#
# protectedDiv(mul(getNConss, getNConss), sub(10000000, getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, sub(add(getNConss, 10000000), getDepth))
# mean solving time or gap:  0.52
#
# protectedDiv(getNVars, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.32
#
# protectedDiv(sub(getDualboundRoot, getEstimate), 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, 10000000)
# mean solving time or gap:  0.58
#
# protectedDiv(10000000, mul(getEstimate, getEstimate))
# mean solving time or gap:  0.52
#
# protectedDiv(getNVars, sub(add(10000000, 10000000), getEstimate))
# mean solving time or gap:  0.53
#
# protectedDiv(getLowerbound, protectedDiv(sub(getDualboundRoot, sub(getNVars, add(protectedDiv(add(getDualboundRoot, getNVars), getNVars), getDepth))), getLowerbound))
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, add(10000000, 10000000))
# mean solving time or gap:  0.32
#
# protectedDiv(getNVars, sub(getNVars, getDepth))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, sub(getNConss, getNConss))), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(getEstimate, getNVars)
# mean solving time or gap:  0.53
#
# add(getDualboundRoot, add(sub(mul(10000000, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getNConss, getEstimate), getLowerbound), getLowerbound), 10000000), sub(getDualboundRoot, add(10000000, getDepth))), 10000000)))
# mean solving time or gap:  0.52
#
# protectedDiv(getLowerbound, protectedDiv(sub(getDualboundRoot, sub(getNVars, add(protectedDiv(add(getDepth, getNVars), getNVars), getEstimate))), getLowerbound))
# mean solving time or gap:  0.47
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getDepth, getEstimate), getLowerbound), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), sub(getDualboundRoot, add(10000000, getDualboundRoot))), 10000000)))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(protectedDiv(protectedDiv(getEstimate, mul(add(getEstimate, getNConss), getNVars)), 10000000), add(getNConss, getLowerbound))))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getDualboundRoot)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.47
#
# protectedDiv(getDepth, getNConss)
# mean solving time or gap:  0.52
#
# 3  	28    	0.456667	0.0679379	0.32	0.58
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(10000000, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# mul(protectedDiv(sub(getNConss, getNVars), add(getDepth, getDualboundRoot)), getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(mul(10000000, getDualboundRoot), getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(getNVars, sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, add(getNVars, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(10000000, 10000000))
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(mul(getNConss, getNVars), sub(10000000, getNConss))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, protectedDiv(getNConss, sub(protectedDiv(protectedDiv(getEstimate, mul(add(getEstimate, getNConss), getNVars)), 10000000), add(getNConss, getLowerbound))))
# mean solving time or gap:  0.52
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(getNVars, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.53
#
# protectedDiv(getDualboundRoot, 10000000)
# mean solving time or gap:  0.58
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(protectedDiv(getEstimate, mul(add(getEstimate, getNConss), getNVars)), getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(protectedDiv(10000000, 10000000), add(getNConss, getLowerbound))))
# mean solving time or gap:  0.62
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, protectedDiv(getNVars, sub(protectedDiv(protectedDiv(getEstimate, mul(add(getEstimate, getNConss), getNVars)), 10000000), add(getNConss, getLowerbound))))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(10000000, getNConss)), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.32
#
# protectedDiv(protectedDiv(10000000, getNVars), mul(protectedDiv(mul(getEstimate, protectedDiv(10000000, getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.43
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(10000000, getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, getEstimate)), getNVars)), getNVars)
# mean solving time or gap:  0.41
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getDepth, getEstimate), 10000000), getLowerbound), mul(add(getEstimate, getNConss), getDualboundRoot)), sub(getDualboundRoot, add(10000000, getDualboundRoot))), 10000000)))
# mean solving time or gap:  0.47
#
# protectedDiv(protectedDiv(getDualboundRoot, getDualboundRoot), getNConss)
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, mul(protectedDiv(mul(10000000, protectedDiv(add(10000000, 10000000), getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.47
#
# protectedDiv(getEstimate, 10000000)
# mean solving time or gap:  0.41
#
# 4  	26    	0.444333	0.0609745	0.32	0.62
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(10000000, add(10000000, 10000000))), 10000000), getEstimate))
# mean solving time or gap:  0.53
#
# protectedDiv(10000000, add(protectedDiv(sub(getNConss, getNVars), add(getDepth, getDualboundRoot)), getEstimate))
# mean solving time or gap:  0.41
#
# mul(getNVars, getNConss)
# mean solving time or gap:  0.53
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.37
#
# protectedDiv(10000000, mul(protectedDiv(getEstimate, 10000000), getEstimate))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, add(getNVars, mul(getEstimate, protectedDiv(10000000, getNVars))))
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, protectedDiv(getLowerbound, getNConss))
# mean solving time or gap:  0.47
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.37
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(protectedDiv(mul(10000000, protectedDiv(10000000, getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.47
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.58
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNVars), getNConss)), protectedDiv(mul(getNVars, protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.52
#
# protectedDiv(add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), getEstimate), getNVars)), getNVars)
# mean solving time or gap:  0.58
#
# protectedDiv(mul(getNConss, getEstimate), 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, getEstimate)
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, mul(protectedDiv(mul(getEstimate, protectedDiv(protectedDiv(getEstimate, mul(getNConss, getNVars)), getNVars)), 10000000), getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(10000000, add(getEstimate, getNConss))), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(10000000, getNVars)), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, getEstimate)), getNConss)), getNVars)
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, getEstimate)), getNVars)))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getNVars, getEstimate), getNVars)
# mean solving time or gap:  0.41
#
# add(getDualboundRoot, add(sub(mul(getEstimate, getDepth), getEstimate), mul(add(protectedDiv(protectedDiv(mul(sub(getDepth, getEstimate), 10000000), getLowerbound), 10000000), sub(getDualboundRoot, add(10000000, getDualboundRoot))), 10000000)))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(add(getEstimate, getNConss), getDualboundRoot))
# mean solving time or gap:  0.37
#
# 5  	28    	0.440667	0.0582485	0.37	0.58
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(getLowerbound, mul(getEstimate, protectedDiv(10000000, getNVars))), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, add(getNVars, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNConss), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNVars, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.32
#
# protectedDiv(getNConss, getEstimate)
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, add(getNVars, getEstimate))
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, add(protectedDiv(sub(getNConss, getNVars), add(getDepth, getDualboundRoot)), getNConss))
# mean solving time or gap:  0.32
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getNConss, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, add(10000000, getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(10000000, add(getEstimate, getNConss))), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, getEstimate)), getNVars))), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(add(getEstimate, protectedDiv(getNConss, getDepth)), getDualboundRoot))
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, getEstimate)
# mean solving time or gap:  0.37
#
# protectedDiv(add(10000000, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.32
#
# protectedDiv(add(getDualboundRoot, mul(10000000, getNVars)), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.58
#
# mul(getNVars, getNConss)
# mean solving time or gap:  0.47
#
# add(getNConss, getDualboundRoot)
# mean solving time or gap:  0.58
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, add(getEstimate, getNConss))), getNVars)))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(getEstimate, getDualboundRoot))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(10000000, add(sub(getNConss, getNConss), getNConss))), protectedDiv(mul(protectedDiv(mul(10000000, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, getNConss)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(getEstimate, getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getEstimate, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.58
#
# protectedDiv(10000000, mul(add(getNConss, getNConss), getDualboundRoot))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, mul(add(add(getNVars, getEstimate), getNConss), getDualboundRoot))
# mean solving time or gap:  0.58
#
# protectedDiv(getEstimate, getNVars)
# mean solving time or gap:  0.69
#
# 6  	28    	0.431333	0.0940118	0.32	0.69
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss)), protectedDiv(10000000, getLowerbound))
# mean solving time or gap:  0.69
#
# protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), 10000000)
# mean solving time or gap:  0.47
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getNVars), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.53
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNVars))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.58
#
# protectedDiv(getNConss, getEstimate)
# mean solving time or gap:  0.89
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getNConss, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(10000000, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.62
#
# protectedDiv(protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound), getNVars)
# mean solving time or gap:  0.52
#
# protectedDiv(add(10000000, mul(protectedDiv(10000000, getNVars), getNConss)), 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, getDualboundRoot), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.58
#
# protectedDiv(10000000, add(protectedDiv(sub(getNConss, getNVars), add(getDepth, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)))), getNConss))
# mean solving time or gap:  0.47
#
# add(sub(10000000, sub(getNConss, getNConss)), getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, add(getNVars, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getNConss, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.83
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getNConss, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.43
#
# protectedDiv(getEstimate, protectedDiv(getLowerbound, getDualboundRoot))
# mean solving time or gap:  0.58
#
# protectedDiv(getDualboundRoot, getNConss)
# mean solving time or gap:  0.53
#
# protectedDiv(getDualboundRoot, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getEstimate, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound))
# mean solving time or gap:  0.74
#
# protectedDiv(10000000, add(protectedDiv(sub(getNConss, getNVars), getNVars), getNConss))
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, add(getDepth, getDualboundRoot))
# mean solving time or gap:  0.53
#
# protectedDiv(10000000, protectedDiv(sub(getNConss, getNVars), add(getDepth, getDualboundRoot)))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, add(add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, add(getEstimate, getNConss))), getNVars)), getNConss))
# mean solving time or gap:  0.52
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, getEstimate)
# mean solving time or gap:  0.41
#
# 7  	24    	0.500667	0.141773 	0.32	0.89
# protectedDiv(getLowerbound, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getNConss, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(10000000, getNConss)), 10000000), 10000000))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getEstimate))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getNConss, getNConss)), 10000000), getLowerbound), getEstimate)
# mean solving time or gap:  0.47
#
# protectedDiv(getDualboundRoot, getNVars)
# mean solving time or gap:  0.32
#
# protectedDiv(getDualboundRoot, add(mul(getLowerbound, protectedDiv(10000000, getNVars)), protectedDiv(getEstimate, add(mul(getNConss, getNConss), getDepth))))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.52
#
# protectedDiv(add(getDualboundRoot, getEstimate), protectedDiv(10000000, getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(getNConss, getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, protectedDiv(sub(getNConss, mul(getDualboundRoot, protectedDiv(getDepth, 10000000))), add(add(getNVars, getEstimate), getDualboundRoot)))
# mean solving time or gap:  0.37
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, getNConss)
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getNVars, getEstimate), getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(sub(getNConss, getNConss), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss))), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, sub(mul(protectedDiv(getDepth, sub(getNConss, getDualboundRoot)), getLowerbound), sub(getDualboundRoot, getDualboundRoot)))
# mean solving time or gap:  0.47
#
# protectedDiv(getNConss, add(getEstimate, getEstimate))
# mean solving time or gap:  0.37
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, add(getEstimate, getNConss))), getNVars)))
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, add(getNConss, getNConss))
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.32
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getEstimate)
# mean solving time or gap:  0.41
#
# add(sub(10000000, sub(getNConss, getNConss)), getNVars)
# mean solving time or gap:  0.41
#
# 8  	28    	0.397667	0.0489001	0.32	0.52
# protectedDiv(10000000, add(getNConss, getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, add(getEstimate, getNConss))), getNVars)))
# mean solving time or gap:  0.32
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getEstimate))), getNConss)), protectedDiv(add(getNConss, getNConss), getLowerbound))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getNVars, getEstimate), getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, getNVars)
# mean solving time or gap:  0.41
#
# sub(getEstimate, sub(getDualboundRoot, getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(getEstimate, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, add(getEstimate, 10000000))
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(10000000, protectedDiv(getNConss, getNConss)), getEstimate)), protectedDiv(mul(protectedDiv(mul(getLowerbound, getEstimate), sub(getEstimate, getNConss)), 10000000), 10000000))
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(getNVars, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(getEstimate, getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, 10000000)
# mean solving time or gap:  0.41
#
# mul(getNVars, 10000000)
# mean solving time or gap:  0.37
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(sub(getNConss, getNConss), getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.52
#
# protectedDiv(mul(sub(getDepth, getNConss), getNVars), getNVars)
# mean solving time or gap:  0.52
#
# protectedDiv(getDualboundRoot, getEstimate)
# mean solving time or gap:  0.58
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(getNVars, sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss))), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, mul(sub(getNConss, getNConss), getDualboundRoot))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), add(getEstimate, getEstimate)), getNVars)))
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, mul(getNConss, add(getEstimate, getNConss)))
# mean solving time or gap:  0.37
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.37
#
# protectedDiv(add(getNConss, getNConss), getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(getNVars, protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss)))
# mean solving time or gap:  0.41
#
# protectedDiv(mul(getNVars, getNVars), getNConss)
# mean solving time or gap:  0.32
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNVars, getNConss), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.37
#
# 9  	30    	0.413667	0.0512824	0.32	0.58
# protectedDiv(getNVars, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(mul(getNVars, 10000000), getNConss)
# mean solving time or gap:  0.41
#
# mul(getNVars, mul(sub(add(protectedDiv(getDualboundRoot, 10000000), protectedDiv(add(getNConss, getDualboundRoot), getDepth)), getDepth), getDualboundRoot))
# mean solving time or gap:  0.47
#
# protectedDiv(10000000, 10000000)
# mean solving time or gap:  0.37
#
# protectedDiv(getDualboundRoot, mul(sub(getNVars, getNConss), getDualboundRoot))
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNConss, add(getEstimate, getNConss))), getNConss)))
# mean solving time or gap:  0.37
#
# mul(10000000, 10000000)
# mean solving time or gap:  0.32
#
# protectedDiv(getNVars, getNVars)
# mean solving time or gap:  0.32
#
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(mul(getNConss, add(getEstimate, getNConss)), add(getEstimate, getEstimate))
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(add(sub(sub(getNConss, getNVars), getNConss), getNConss), getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, mul(protectedDiv(mul(sub(getNConss, 10000000), getDualboundRoot), sub(getNConss, getNConss)), protectedDiv(getLowerbound, 10000000)))
# mean solving time or gap:  0.41
#
# protectedDiv(getNConss, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(10000000, add(10000000, sub(protectedDiv(protectedDiv(getNVars, getEstimate), mul(getNVars, add(getEstimate, getNConss))), getNVars)))
# mean solving time or gap:  0.41
#
# protectedDiv(mul(getNConss, getNVars), getNConss)
# mean solving time or gap:  0.47
#
# protectedDiv(add(getNVars, getNVars), getEstimate)
# mean solving time or gap:  0.41
#
# mul(getEstimate, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(add(getDualboundRoot, mul(protectedDiv(getNVars, protectedDiv(getNVars, sub(getNConss, getNConss))), getNConss)), protectedDiv(mul(protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), add(getDualboundRoot, 10000000)), protectedDiv(getLowerbound, 10000000)), getLowerbound))
# mean solving time or gap:  0.47
#
# mul(getNVars, mul(protectedDiv(getNVars, protectedDiv(mul(sub(getNConss, getNConss), getDualboundRoot), sub(getNConss, getNConss))), getNConss))
# mean solving time or gap:  0.41
#
# protectedDiv(mul(add(protectedDiv(sub(getDualboundRoot, mul(getNConss, getEstimate)), getDualboundRoot), protectedDiv(getEstimate, getDepth)), getEstimate), 10000000)
# mean solving time or gap:  0.41
#
# mul(getNVars, 10000000)
# mean solving time or gap:  0.41
#
# protectedDiv(sub(getNConss, getNConss), getNVars)
# mean solving time or gap:  0.41
#
# protectedDiv(getEstimate, getEstimate)
# mean solving time or gap:  0.41
#
# protectedDiv(getDualboundRoot, getEstimate)
# mean solving time or gap:  0.32
#
# sub(getEstimate, sub(sub(getNConss, getNConss), getLowerbound))
# mean solving time or gap:  0.32
#
# protectedDiv(getDualboundRoot, mul(sub(getNConss, getNConss), getDualboundRoot))
# mean solving time or gap:  0.32
#
# protectedDiv(mul(add(getLowerbound, protectedDiv(getNConss, add(getDepth, getDepth))), getNVars), 10000000)
# mean solving time or gap:  0.47
#
# 10 	28    	0.400333	0.0429328	0.32	0.47
# [[<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4380>, <deap.gp.Terminal object at 0x000001BD015B4600>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Terminal object at 0x000001BD015B4380>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Terminal object at 0x000001BD015B4300>], [<deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Terminal object at 0x000001BD015B4380>, <deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD7FA01340>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD7FA01340>, <deap.gp.Terminal object at 0x000001BD01539F40>, <deap.gp.Terminal object at 0x000001BD01539F40>, <deap.gp.Terminal object at 0x000001BD7FA01340>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Terminal object at 0x000001BD015B4600>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD7FA01340>, <deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Terminal object at 0x000001BD015B4380>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD7FA01340>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4380>, <deap.gp.Terminal object at 0x000001BD01591600>, <deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Terminal object at 0x000001BD01591600>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD015B4300>], [<deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Terminal object at 0x000001BD015B4600>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4380>, <deap.gp.Terminal object at 0x000001BD015B4380>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD015B4600>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Terminal object at 0x000001BD01591600>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Terminal object at 0x000001BD01591600>, <deap.gp.Terminal object at 0x000001BD01591600>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD7FA01340>, <deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Primitive object at 0x000001BD015E76A0>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD7FA01340>, <deap.gp.Terminal object at 0x000001BD015B4300>], [<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Primitive object at 0x000001BD0158D7B0>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal ob ...
# 0  	30    	0.516   	0.0985427	0.37	0.76
# 1  	25    	0.508667	0.132054 	0.28	0.91
# 2  	30    	0.442   	0.0620967	0.37	0.62
# 3  	28    	0.456667	0.0679379	0.32	0.58
# 4  	26    	0.444333	0.0609745	0.32	0.62
# 5  	28    	0.440667	0.0582485	0.37	0.58
# 6  	28    	0.431333	0.0940118	0.32	0.69
# 7  	24    	0.500667	0.141773 	0.32	0.89
# 8  	28    	0.397667	0.0489001	0.32	0.52
# 9  	30    	0.413667	0.0512824	0.32	0.58
# 10 	28    	0.400333	0.0429328	0.32	0.47 <deap.tools.support.Statistics object at 0x000001BD001B89D0> [[<deap.gp.Primitive object at 0x000001BD015E7650>, <deap.gp.Terminal object at 0x000001BD015B4600>, <deap.gp.Primitive object at 0x000001BD015E71A0>, <deap.gp.Terminal object at 0x000001BD015B4300>, <deap.gp.Terminal object at 0x000001BD015B4300>]]
# protectedDiv(10000000, sub(getNConss, getNConss))
# {'gen': 0, 'nevals': 30, 'avg': 0.516, 'std': 0.09854271493452303, 'min': 0.37, 'max': 0.76}
# {'gen': 1, 'nevals': 25, 'avg': 0.5086666666666667, 'std': 0.13205386106518135, 'min': 0.28, 'max': 0.91}
# {'gen': 2, 'nevals': 30, 'avg': 0.442, 'std': 0.062096698785040094, 'min': 0.37, 'max': 0.62}
# {'gen': 3, 'nevals': 28, 'avg': 0.4566666666666667, 'std': 0.06793788012262052, 'min': 0.32, 'max': 0.58}
# {'gen': 4, 'nevals': 26, 'avg': 0.4443333333333334, 'std': 0.06097449375672494, 'min': 0.32, 'max': 0.62}
# {'gen': 5, 'nevals': 28, 'avg': 0.44066666666666665, 'std': 0.05824850975680741, 'min': 0.37, 'max': 0.58}
# {'gen': 6, 'nevals': 28, 'avg': 0.4313333333333333, 'std': 0.09401181958787, 'min': 0.32, 'max': 0.69}
# {'gen': 7, 'nevals': 24, 'avg': 0.5006666666666667, 'std': 0.14177290134421158, 'min': 0.32, 'max': 0.89}
# {'gen': 8, 'nevals': 28, 'avg': 0.39766666666666667, 'std': 0.04890012497143767, 'min': 0.32, 'max': 0.52}
# {'gen': 9, 'nevals': 30, 'avg': 0.4136666666666666, 'std': 0.05128244230620153, 'min': 0.32, 'max': 0.58}
# {'gen': 10, 'nevals': 28, 'avg': 0.4003333333333334, 'std': 0.04293276397137997, 'min': 0.32, 'max': 0.47}

# %% [markdown]
# For example, with an initial population of 30 and 10 generations, GP2S converged to the following function: `protectedDiv(10000000, sub(getNConss, getNConss))`.

# %% [markdown]
# ## Convergence Plot
#
# The performance of the GP method across generations can be visualized. It is important to note that, since the training set is small and the problems are simple, the convergence plot may not necessarily show the desired form (e.g., a decrease in average solution time over generations).

# %%
from artificial_pbs.evaluation_convergence_of_GP_over_gens_articial_pbs import *

# Define the folder containing simulation results (defaults to the first element in this folder)
simulation_folder = os.path.join(conf.ROOT_DIR, "outcomes_jupyter")

# Evaluate the convergence of GP across generations
gp_function = convergence_of_gp_over_generations(simulation_folder,saving=False)
# Out:
# C:\Users\gwen.maudet\OneDrive - University of Luxembourg\Documents\programs\PycharmProjects\post doc lux\genetic_programming_search_strategy\outcomes_jupyter\GP_function\gisp_pop_30_nb_gen10_seed_0.json
# the best GP function is  protectedDiv(10000000, sub(getNConss, getNConss))

# %% [markdown]
# ## Evaluation of the Method on the Test Set
#
# In this section, we compare the GP-produced method to the following:
# - The standalone SCIP method
# - The handcrafted methods used in the paper:
#     - BE BFS
#     - BE DFS
#     - LB BFS
#
# We do not compare the GNN method, as it also requires training. Readers are encouraged to visit the repository [https://github.com/ds4dm/learn2comparenodes](https://github.com/ds4dm/learn2comparenodes) for further details.

# %%
from artificial_pbs.evaluation_artificial_problems import *
gp_func_dic = {"1.2":gp_function}#1.2 is meant for the parsimony parameter
print(gp_function)
problem = "gisp"
partition= "test_for_jupyter"
evaluation_gnn_gp(problem, partition, gp_func_dic,do_gnn=False, build_set_of_instances=False,saving_folder="outcomes_jupyter")
# Out:
# protectedDiv(10000000, sub(getNConss, getNConss))
# here we go again
# result for test_for_jupyter GP_function and SCIP :  perfs are done for the function  GP_parsimony_parameter_1.2
# perfs are done for the function  SCIP
# perfs are done for the function  best_estimate_BFS
# perfs are done for the function  best_estimate_DFS
# perfs are done for the function  best_LB_BFS
# It is ok for GP_function and the SCIP baseline
#
# one is done, with total of  1
# result for test_for_jupyter GP_function and SCIP :  perfs are done for the function  GP_parsimony_parameter_1.2
# perfs are done for the function  SCIP
# perfs are done for the function  best_estimate_BFS
# perfs are done for the function  best_estimate_DFS
# perfs are done for the function  best_LB_BFS
# It is ok for GP_function and the SCIP baseline
#
# one is done, with total of  2
# result for test_for_jupyter GP_function and SCIP :  perfs are done for the function  GP_parsimony_parameter_1.2
# perfs are done for the function  SCIP
# perfs are done for the function  best_estimate_BFS
# perfs are done for the function  best_estimate_DFS
# perfs are done for the function  best_LB_BFS
# It is ok for GP_function and the SCIP baseline
#
# one is done, with total of  3
# result for test_for_jupyter GP_function and SCIP :  perfs are done for the function  GP_parsimony_parameter_1.2
# perfs are done for the function  SCIP
# perfs are done for the function  best_estimate_BFS
# perfs are done for the function  best_estimate_DFS
# perfs are done for the function  best_LB_BFS
# It is ok for GP_function and the SCIP baseline
#
# one is done, with total of  4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 problem = "gisp"
#       5 partition= "test_for_jupyter"
# ----> 6 evaluation_gnn_gp(problem, partition, gp_func_dic,do_gnn=False, build_set_of_instances=False,saving_folder="outcomes_jupyter")
#
# File ~\OneDrive - University of Luxembourg\Documents\programs\PycharmProjects\post doc lux\genetic_programming_search_strategy\artificial_pbs\evaluation_artificial_problems.py:58, in evaluation_gnn_gp(problem, partition, gp_func_dic, do_gnn, build_set_of_instances, saving_folder)
#      56 # solving GP_function and heuristics and SCIP
#      57 GP_and_SCIP = os.path.join(conf.ROOT_DIR, "artificial_pbs/subprocess_evaluation_gp_SCIPbaseline.py")
# ---> 58 result = subprocess.run(
#      59     ['python', GP_and_SCIP, problem, partition, json_gp_func_dic, instance],
#      60     capture_output=True, text=True)
#      61 print("result for", partition, "GP_function and SCIP : ", result.stdout)
#      63 if "It is ok for GP_function and the SCIP baseline" not in result.stdout:
#
# File ~\AppData\Local\anaconda3\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~\AppData\Local\anaconda3\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~\AppData\Local\anaconda3\Lib\subprocess.py:1626, in Popen._communicate(self, input, endtime, orig_timeout)
#    1622 # Wait for the reader threads, or time out.  If we time out, the
#    1623 # threads remain reading and the fds left open in case the user
#    1624 # calls communicate again.
#    1625 if self.stdout is not None:
# -> 1626     self.stdout_thread.join(self._remaining_time(endtime))
#    1627     if self.stdout_thread.is_alive():
#    1628         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\AppData\Local\anaconda3\Lib\threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Local\anaconda3\Lib\threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Output of the Results
#
# To display the results, we choose to print them directly. To display the table format for LaTeX with the appropriate colors, you need to use `build_table_with_cell_colors(dic_info)` .

# %%
from artificial_pbs.build_tables_artificial_pb_perfs import *

# Gather information from JSON files for the specified problems and partitions
dic_info = gather_info_from_json_files(problems=["gisp"], partitions=["test_for_jupyter"], saving_folder="outcomes_jupyter")

# Display the output results
just_get_the_output_results(dic_info)
# Out:
# geometric mean solving time for set test_for_jupyter for method best_estimate_BFS is $0.54\pm 3.0$ on 50 instances
# geometric mean solving time for set test_for_jupyter for method best_estimate_DFS is $0.3\pm 4.5$ on 50 instances
# geometric mean solving time for set test_for_jupyter for method best_LB_BFS is $0.41\pm 3.6$ on 50 instances
# geometric mean solving time for set test_for_jupyter for method GP_parsimony_parameter_1.2 is $0.36\pm 3.9$ on 50 instances
# geometric mean solving time for set test_for_jupyter for method SCIP is $0.28\pm 4.7$ on 50 instances
# RESULTS FOR gisp - test_for_jupyter
# results for function BE BFS are 0.5 +-3.0
# results for function BE DFS are 0.3 +-4.5
# results for function LB BFS are 0.4 +-3.6
# results for function GP2S are 0.4 +-3.9
# results for function SCIP are 0.3 +-4.7
